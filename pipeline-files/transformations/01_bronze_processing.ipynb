# %%
import dlt


# Bronze: raw ingestion of three delta streams
# Raw Temperature
@dlt.table(
  name = "01_bronze.bridge_temperature",
  comment = "Raw temperature readings"
)
def bronze_bridge_temperature():
  return(
    spark.readStream.format("delta").load("/Volumes/bridge_monitoring/00_landing/streaming/bridge_temperature")
  )

#Raw Vibrations
@dlt.table(
  name = "01_bronze.bridge_vibration",
  comment = "Raw vibration readings"
)

def bronze_bridge_vibration():
  return (
    spark.readStream.format("delta").load("/Volumes/bridge_monitoring/00_landing/streaming/bridge_vibration")
  )

# Raw Bridge tilt

@dlt.table(
  name = "01_bronze.bridge_tilt",
  comment = "Raw tilt readings"
)
def bronze_bridge_tilt():
  return (
    spark.readStream.format("delta").load("/Volumes/bridge_monitoring/00_landing/streaming/bridge_tilt")
  )
